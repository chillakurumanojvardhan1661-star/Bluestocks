# %% [markdown]
# # Day 6: Advanced Analytics & Risk Metrics
# **Mutual Fund Analytics Platform - Bluestock Fintech**
#
# This notebook covers the advanced risk and demographic metrics computed for the capstone project, including Value at Risk (VaR 95%), Conditional VaR (CVaR), sector HHI concentrations, cohort analysis, and investor SIP continuation gaps.

# %%
import pandas as pd
import os

PROCESSED_DIR = "../data/processed"
df_var = pd.read_csv(os.path.join(PROCESSED_DIR, "var_cvar_report.csv"))
df_hhi = pd.read_csv(os.path.join(PROCESSED_DIR, "sector_hhi.csv"))
df_cohort = pd.read_csv(os.path.join(PROCESSED_DIR, "cohort_analysis.csv"))
df_sip_cont = pd.read_csv(os.path.join(PROCESSED_DIR, "sip_continuity.csv"))

# %% [markdown]
# ### Value at Risk (VaR 95%) & CVaR (First 5 Schemes)

# %%
df_var.head(5)

# %% [markdown]
# ### Sector HHI Concentration (First 5 Schemes)

# %%
df_hhi.head(5)

# %% [markdown]
# ### Investor Cohort Analysis

# %%
df_cohort

# %% [markdown]
# ### SIP Gaps & At-Risk Investors (First 5)

# %%
df_sip_cont.head(5)
