# %% [markdown]
# # Day 3: Exploratory Data Analysis (EDA)
# **Mutual Fund Analytics Platform - Bluestock Fintech**
#
# This notebook documents the Exploratory Data Analysis (EDA) of the mutual fund database, exploring historical NAVs, AUM growth, SIP inflows, and investor demographics.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

FIG_DIR = "../reports/figures"
print("Generated Figures:")
for fig in sorted(os.listdir(FIG_DIR)):
    if fig.endswith('.png'):
        print(fig)

# %% [markdown]
# ### EDA Insights Summary
#
# 1. **NAV Trends**: Standard large-cap bluechip funds show a steady growth pattern with minor corrections, reflecting the broader market trends (Nifty 50 / Nifty 100).
# 2. **AUM Concentration**: SBI Mutual Fund maintains a dominant position, followed by HDFC and ICICI Prudential Mutual Funds.
# 3. **SIP Inflow Milestones**: Monthly SIP inflows peaked in December 2025 at **Rs. 31,002 Crore**, showing strong retail participation.
# 4. **Demographics**: Major investments are driven by the age groups **26-35** and **36-45**, utilizing net banking and UPI payment modes.
# 5. **Geographics**: A significant portion of SIP transactions originates from top states like Maharashtra, Gujarat, Karnataka, and Punjab, with a T30 (Top 30) city dominance of roughly 66%.
