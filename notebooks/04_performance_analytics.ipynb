# %% [markdown]
# # Day 4: Fund Performance Analytics
# **Mutual Fund Analytics Platform - Bluestock Fintech**
#
# This notebook demonstrates the calculation of key fund performance and risk metrics (annualised return, CAGR, Sharpe ratio, Sortino ratio, Alpha, Beta, and Max Drawdown) from NAV history. It also presents the final composite fund ranking scorecard.

# %%
import pandas as pd
import os

SCORECARD_PATH = "../data/processed/fund_scorecard.csv"
df_scorecard = pd.read_csv(SCORECARD_PATH)
print("Fund Scorecard Columns:", df_scorecard.columns.tolist())
print("Shape:", df_scorecard.shape)

# %% [markdown]
# ### Top 5 Mutual Fund Schemes (by Composite Score)
# The composite score (0-100) is calculated based on: 30% 3-year return, 25% Sharpe ratio, 20% Alpha, 15% lower expense ratio, and 10% lower Max Drawdown.

# %%
df_scorecard.head(5)

# %% [markdown]
# ### Summary of Insights
# 1. **High Performers**: Small Cap and Mid Cap schemes dominate the top composite scores due to high 3-year CAGRs and strong Sharpe ratios.
# 2. **Risk-Adjusted Returns**: Funds with Sharpe ratios > 1.0 demonstrate excellent risk-return efficiency.
# 3. **Alpha Generation**: Successful active managers generated significant positive alpha against the Nifty 100 benchmark.
